# %%
list_ = [1,2,3,4,5,6,7,8,9,0]
def summator (x,y = 2):
  return x*y
  print('x*y',x*y)

# summator(10,5)

# result = map(summator,list_)
# for i in result:
#   print(i)

list(map(summator,list_))
result = lambda x,y: x*y
result(100,10)
# Out:
# 1000

# %%
check = lambda x: 'even' if x % 2 == 0 else 'odd'
list(map(check,list_))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even']

# %%
def is_a_in_string (string):
  if 'a' in string:
    print("String has a")
    return True
  else:
    print("String has not a")
    return False

string_list = ['hi','was','his','many']

print(list(map(is_a_in_string,string_list)))
# Out:
# String has not a
# String has a
# String has not a
# String has a
# [False, True, False, True]

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}


def doc_ch_and_del(number,del_ = False,mov_ = False):
  i = 0
  x = False
  for el in documents:
    if el['number']==number:
      x = True
      break
    else:
      i += 1
  if x == False:
    print('Документ не найден в базе.')
    return 0
  elif del_ == True and x == True:
    del documents[i]
    print('-------------ветка удаления----------------')
    print('Документ удален.')  
  elif del_ == False and x == True:
    print('-------------ветка перемещения----------------')
    new_sh = input('Введите номер полки: ')
    if shlv_ch (new_sh) == True:
      print('------------- ПЕРЕМЕЩАЕМ----------------')
      directories[dir_ch(number)].remove(number)
      directories[new_sh].append(number)
      print('Документ перемещен')
      comm('l')
    else:
      print('Такой полки не существует.',end=' ')
      print(f'Текущий перечень полок: {sh()}')


def dir_ch (s,p=False):
  i = 0
  for el in directories.items():
      for ell in el[1]:
        if ell == s:
          if p==True:
            print('Документ хранится на полке: ',el[0])
          else:
            return el[0]
        else:
          i += 1
        if i == len(documents):
          print('Документ не найден в базе')  


def shlv_ch (num):
  if num in directories.keys():
    return True
  else:
    return False


def sh ():
  # print ('Текущий перечень полок:', end = ' ')
  s = ",".join(list(directories.keys())) 
  return s


def start ():
  x = input('Введите команду: ').lower()
  comm(x)
  return x


def comm (x):
  if x == 'p':
    p = input('Введите номер документа: ').lower()
    i = 0
    for e in documents:
      if e['number'] == p:
        print('Владелец документа: ',e['name'])
      else:
        i += 1
        if i == len(documents):
          print('Документ не найден в базе')

  if x == 's':
    s = input('Введите номер документа: ').lower()
    dir_ch(s,True)
  
  if x == 'l':
    print('Текущий список документов:')
    for el in documents:
      print(f'№: {el["number"]}, тип: {el["type"]}, владелец: {el["name"]}, полка хранения: {dir_ch(el["number"])}')

  if x == 'as':
    as_ = input('Введите номер полки: ')
    if as_ in directories.keys():
      print(f'Такая полка уже существует. Текущий перечень полок: {sh()}.')
    else:
      directories[as_]=[]
      print(f'Полка добавлена. Текущий перечень полок: {sh()}')

  if x == 'ds':
    ds = input('Введите номер полки: ')
    if ds in directories.keys():
      if directories[ds] == []:
        del directories[ds]
        print(f'Полка удалена. Текущий перечень полок: {sh()}.')
      else:
        print(f'На полке есть документЫ, удалите их перед удалением полки. Текущий перечень полок: {sh()}.')
    else:
      print(f'Такой полки не существует. Текущий перечень полок: {sh()}.')

  if x == 'ad':
    nu = input('Введите номер документа: ')
    t = input('Введите тип документа: ')
    na = input('Введите владельца документа: ')
    shlv = input('Введите полку для хранения: ')
    if shlv_ch(shlv) == True:
      documents.append({'type' : t,'number' : nu,'name' : na})
      directories[shlv].append(nu)4343
      print ('Документ добавлен.', end = ' ')
      comm('l')
    else:
      print('Такой полки не существует. Добавьте полку командой as')

  if x == 'd':
    d = input('Введите номер документа: ')
    doc_ch_and_del(d,True)
    comm('l')

  if x == 'm':
    m = input('Введите номер документа: ')
    x = doc_ch_and_del(m)
    if x == 0 : comm('l')
    


while start() != 'q':
  print('-----------')
  


print('Good bye!')
# Out:
# Введите команду: ad
# Введите номер документа: 43
# Введите тип документа:
# Введите владельца документа: 43
# Введите полку для хранения: 2
# Документ добавлен. Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# №: 43, тип: , владелец: 43, полка хранения: 2
# -----------
# Введите команду: d
# Введите номер документа: 10006
# -------------ветка удаления----------------
# Документ удален.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# Документ не найден в базе
# №: 43, тип: , владелец: 43, полка хранения: 2
# -----------
# Введите команду: l
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# ...

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

directories['1'].append('11111')
directories
# Out:
# {'1': ['2207 876234', '11-2', '11111'], '2': ['10006'], '3': []}

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

directories['1'].remove('11-2')
directories
# Out:
# {'1': ['2207 876234'], '2': ['10006'], '3': []}

# %%
# Задание 2
# Дана переменная, в которой хранится список поисковых запросов пользователя (пример структуры данных приведен ниже). Вам необходимо написать программу, которая выведет на экран распределение количества слов в запросах в требуемом виде.

# Пример работы программы:

# queries = [
# 'смотреть сериалы онлайн',
# 'новости спорта',
# 'афиша кино',
# 'курс доллара',
# 'сериалы этим летом',
# 'курс по питону',
# 'сериалы про спорт',
# ]
# Результат:

# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%


queries = [
'смотреть сериалы онлайн',
'новости спорта',
'афиша кино',
'курс доллара',
'сериалы этим летом',
'курс по питону',
'сериалы про спорт',
'сериалы сериалы сериалы сериалы сериалы сериалы сериалы сериалы сериалы',
]

q_ = {}

for el in queries:
  a = len(el.split(' '))
  if a in q_:
    q_[a] += 1
  else:
    q_[a] = 1


for i in q_.items():
  print(f'Поисковых запросов, содержащих {i[0]} слов(а): {i[1]/sum(q_.values()):.02%}')
# Out:
# Поисковых запросов, содержащих 3 слов(а): 50.00%
# Поисковых запросов, содержащих 2 слов(а): 37.50%
# Поисковых запросов, содержащих 9 слов(а): 12.50%

# %%
# Задание 4
# Дана переменная, в которой хранится статистика рекламных каналов по объемам продаж (пример структуры данных приведен ниже).
#  Напишите программу, которая возвращает название канала с максимальным объемом продаж.

# Пример работы программы:

# stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}

# Результат: Максимальный объем продаж на рекламном канале: vk

stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}

""" a) create a list of the dict's keys and values; 
    b) return the key with the max value"""  
v=list(stats.values())
k=list(stats.keys())
k[v.index(max(v))]
# Out:
# 'vk'

# %%
cook_book = {
'салат': [
{'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
{'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
{'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
{'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
],
'пицца': [
{'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
{'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
{'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
{'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},
],
'лимонад': [
{'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
{'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
{'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
{'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},
]
}


person = 3
shop_dict = {}
for dish in cook_book.values():
  for ingr in dish:
    key = (ingr['ingridient_name'], ingr['measure'])
    if key not in shop_dict:
        shop_dict[key] = ingr['quantity'] * person
    else:
        shop_dict[key] += ingr['quantity'] * person


for name, q in shop_dict.items():
	print(f'{name[0]}: {q} {name[1]}')
# Out:
# сыр: 210 гр
# томаты: 6 шт
# огурцы: 60 гр
# маслины: 30 гр
# оливковое масло: 60 мл
# салат: 30 гр
# перец: 60 гр
# колбаса: 90 гр
# бекон: 90 гр
# оливки: 30 гр
# томаты: 60 гр
# тесто: 300 гр
# лимон: 3 шт
# вода: 600 мл
# сахар: 30 гр
# лайм: 60 гр
